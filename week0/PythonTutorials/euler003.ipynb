# %% [markdown]
# # Euler 3
# The prime factors of 13195 are 5, 7, 13 and 29.
#
# What is the largest prime factor of the number 600851475143?

# %%
# Using a function to check primality
def isPrime(n):
    if n == 2 or n == 3:
        return True
    if n % 2 == 0:
        return False
    r = 3
    while r * r <= n:
        if n % r == 0:
            return False
        r += 2
    return True

# %%
isPrime(2), isPrime(7), isPrime(781), isPrime(169)
# Out:
# (True, True, False, False)

# %%
N = 600851475143

# %%
def factorize(n):
    factor = 2
    while n > 2:
        while n % factor == 0:
            yield factor
#             factors.append(factor)
            n //= factor
            print(factor, n)
        factor += 1

# %%
factorize(2)
# Out:
# []

# %%
factorize(192)
# Out:
# <generator object factorize at 0x7fcd40a4c2b0>

# %%
factorize(17)
# Out:
# 17 1
# [17]

# %%
factorize(N)
# Out:
# 71 8462696833
# 839 10086647
# 1471 6857
# 6857 1
# [71, 839, 1471, 6857]

# %%
max(factorize(N))
# Out:
# 71 8462696833
# 839 10086647
# 1471 6857
# 6857 1
# 6857
